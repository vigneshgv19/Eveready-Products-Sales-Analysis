# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Feature Engineering

# %%
df = pd.read_csv('every.xlsx')
df

# %% [markdown]
# # Handling missing value

# %%
df.isnull().sum()

# %%
df=df.dropna()

# %%
df.isnull().sum()

# %% [markdown]
# # Handling Duplicate records

# %%
duplicate = df.duplicated()
duplicate

# %%
duplicate.sum()

# %%
df.drop_duplicates(inplace=True)

# %%
duplicate = df.duplicated()
duplicate

# %%
duplicate.sum()

# %% [markdown]
# # Handling Outlier

# %%
#Quantity outlier check
Q1=df['Quantity'].quantile(0.25)
Q3=df['Quantity'].quantile(0.75)
IQR=Q3-Q1

# %%
Q1

# %%
Q3

# %%
IQR

# %%
#Quantity outlier removed
df=df[~((df['Quantity']>Q3+1.5*IQR)|(df['Quantity']<Q1-1.5*IQR))]

# %% [markdown]
# # Data Visualization

# %% [markdown]
# #Bivariate Analysis

# %%
# Show the count of each SaleType 
for index, value in df['SaleType'].value_counts().iteritems():
    print(index, ': ', value)

# %%
#frequency of Quantity v/s SaleType
plt.figure(figsize = (5, 5))
ax2=sns.catplot(x = 'SaleType',y= "Quantity",data =df)
plt.title('frequency of sales with different SaleType')
plt.xlabel('SaleType')
plt.ylabel('Quantity')
plt.xticks(rotation = 90)

# %%
# Show the count of each Customer_Name
for index, value in df['Month'].value_counts().iteritems():
    print(index, ': ', value)

# %%
#frequency of Quantity v/s Month
plt.figure(figsize = (5, 5))
ax2=sns.barplot(x = 'Month',y= "Quantity",data =df)
plt.title('frequency of sales with different Month')
plt.xlabel('Month')
plt.ylabel('Quantity')
plt.xticks(rotation = 90)

# %%
# Show the count of each Costsectioncode
for index, value in df['Costsectioncode'].value_counts().iteritems():
    print(index, ': ', value)

# %%
#frequency of Quantity v/s Costsectioncode
plt.figure(figsize = (5, 5))
ax2=sns.catplot(x = 'Costsectioncode',y= "Quantity",data =df)
plt.title('frequency of sales with different Costsectioncode')
plt.xlabel('Costsectioncode')
plt.ylabel('Quantity')
plt.xticks(rotation = 90)

# %%
# Show the count of each Groupcode
for index, value in df['Groupcode'].value_counts().iteritems():
    print(index, ': ', value)

# %%
#frequency of Quantity v/s Groupcode
plt.figure(figsize = (10, 6))
ax2=sns.barplot(x = 'Groupcode',y= "Quantity",data =df)
plt.title('frequency of sales with different Groupcode')
plt.xlabel('Groupcode')
plt.ylabel('Quantity')
plt.xticks(rotation = 90)

# %%
# Show the count of each Typecode
for index, value in df['Typecode'].value_counts().iteritems():
    print(index, ': ', value)

# %%
#frequency of Quantity v/s Typecode
plt.figure(figsize = (30,10))
ax2=sns.barplot(x = 'Typecode',y= "Quantity",data =df)
plt.title('frequency of sales with different Typecode')
plt.xlabel('Typecode')
plt.ylabel('Quantity')
plt.xticks(rotation = 90)

# %%
# Show the count of each Productcode
for index, value in df['Productcode'].value_counts().iteritems():
    print(index, ': ', value)

# %%
#frequency of Quantity v/s Productcode
plt.figure(figsize = (30,10))
ax2=sns.barplot(x = 'Productcode',y= "Quantity",data =df)
plt.title('frequency of sales with different Productcode')
plt.xlabel('Productcode')
plt.ylabel('Quantity')
plt.xticks(rotation = 90)

# %%
# Show the count of each Description
for index, value in df['Description'].value_counts().iteritems():
    print(index, ': ', value)

# %%
#frequency of Quantity v/s Description    
plt.figure(figsize = (30,10))
ax2=sns.barplot(x = 'Description',y= "Quantity",data =df)
plt.title('frequency of sales with different Description')
plt.xlabel('Description')
plt.ylabel('Quantity')
plt.xticks(rotation = 90)

# %%
# Show the count of each LotNumber
for index, value in df['LotNumber'].value_counts().iteritems():
    print(index, ': ', value)

# %%
# Show the count of each CustomerName
for index, value in df['CustomerName'].value_counts().iteritems():
    print(index, ': ', value)

# %%
#frequency of Quantity v/s CustomerName    
plt.figure(figsize = (30,10))
ax2=sns.barplot(x = 'CustomerName',y= "Quantity",data =df)
plt.title('frequency of sales with different CustomerName')
plt.xlabel('CustomerName')
plt.ylabel('Quantity')
plt.xticks(rotation = 90)

# %%
# Show the count of each UnitWeight
for index, value in df['UnitWeight'].value_counts().iteritems():
    print(index, ': ', value)

# %%
#frequency of Quantity v/s UnitWeight    
plt.figure(figsize = (30,10))
ax2=sns.barplot(x = 'UnitWeight',y= "Quantity",data =df)
plt.title('frequency of sales with different UnitWeight')
plt.xlabel('UnitWeight')
plt.ylabel('Quantity')
plt.xticks(rotation = 90)

# %%
#frequency of Quantity v/s CustomerName    
plt.figure(figsize = (30,10))
ax2=sns.barplot(x = 'CustomerName',y= "Quantity",data =df)
plt.title('frequency of sales with different CustomerName')
plt.xlabel('CustomerName')
plt.ylabel('Quantity')
plt.xticks(rotation = 90)

# %%
# Show the count of each Lp
for index, value in df['Lp'].value_counts().iteritems():
    print(index, ': ', value)

# %%
# Show the count of each PaymentTerm
for index, value in df['PaymentTerm'].value_counts().iteritems():
    print(index, ': ', value)

# %%
#frequency of Quantity v/s PaymentTerm    
plt.figure(figsize = (5,5))
ax2=sns.barplot(x = 'PaymentTerm',y= "Quantity",data =df)
plt.title('frequency of sales with different PaymentTerm')
plt.xlabel('PaymentTerm')
plt.ylabel('Quantity')
plt.xticks(rotation = 90)

# %% [markdown]
# _________________

# %%
corr=df.corr()
corr

# %%
plt.figure(figsize = (6,6))
sns.heatmap(corr, annot=True, cmap="viridis")

# %%
df.head(10)

# %% [markdown]
# # LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df1=df.copy()

# %%
x_idep = df.drop('Quantity',axis=1)
x_idep

# %%
x_idep.columns

# %%
for x in x_idep.columns:
    if  x != 'Nsv' and x != 'UnitWeight' and x != 'Lp' and x!= 'Costsectioncode':
        x_idep[x] = LabelEncoder().fit_transform(x_idep[x])

# %%
y1=df.Quantity

# %%
for x in df.columns:
    if  x != 'Nsv' and x != 'UnitWeight' and x != 'Lp' and x!= 'Costsectioncode' and x != 'Quantity':
        df[x] = LabelEncoder().fit_transform(df[x])

# %% [markdown]
# # Feature Selection

# %% [markdown]
# # Droping Constant Features Using Variance Threshold

# %%
### It will zero variance features
from sklearn.feature_selection import VarianceThreshold
var_thres=VarianceThreshold(threshold=0)
var_thres.fit(df)

# %%
df.columns[var_thres.get_support()]

# %%
df.shape

# %% [markdown]
# # Feature Selection- With Correlation

# %%
df.corr()

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is correlated with anything other feature

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(df, 0.7)
len(set(corr_features))

# %%
corr_features

# %%
# As we need Description and Lp is needed for analysis, so we drop only Groupcode and Typecode
df=df.drop('Description', axis=1)
df=df.drop('Typecode', axis=1)
df

# %%
x_idep=x_idep.drop('Description', axis=1)
x_idep=x_idep.drop('Typecode', axis=1)
x_idep

# %% [markdown]
# # Information gain - mutual information In Regression

# %%
## It is always a good practice to split train and test data to avoid
#overfitting
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x_idep,y1,
    test_size=0.2,
    random_state=0)

# %%
from sklearn.feature_selection import mutual_info_regression
# determine the mutual information
mutual_info = mutual_info_regression(X_train.fillna(0), y_train)
mutual_info

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending=False)

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(15,5))

# %%
from sklearn.feature_selection import SelectPercentile

# %%
## Selecting the top 70 percentile
selected_top_columns = SelectPercentile(mutual_info_regression, percentile=70)
selected_top_columns.fit(X_train, y_train)

# %%
selected_top_columns.get_support()

# %%
X_train.columns[selected_top_columns.get_support()]

# %%
# As we found in mutual_info_regression 70 percent of fields are considered for analysis, 
# even though month is less related with dependent variable its need for sales analysis
# so we drop only SaleType and PaymentTerm
df=df.drop('SaleType', axis=1)
df=df.drop('PaymentTerm', axis=1)

# %%
# as we splitted the x_idep during feature selection and will use it for all model builbing ,
# so we drop the values in x_idep as well as df(the main data)
x_idep=x_idep.drop('SaleType', axis=1)
x_idep=x_idep.drop('PaymentTerm', axis=1)

# %%
#we drop LotNumber as we will not be able known the LotNumber in future months Quantity perdiction
df=df.drop('LotNumber', axis=1)
x_idep=x_idep.drop('LotNumber', axis=1)

# %%
# As we generally we know Productcode is mostly similar to group code, 
#so we drop Productcode
df=df.drop('Productcode', axis=1)
x_idep=x_idep.drop('Productcode', axis=1)

# %%
# As we will get purchase order number only after pruchase is made
# but we are trying to find the sales Quantity for upcoming months 
df=df.drop('PoNumber', axis=1)
x_idep=x_idep.drop('PoNumber', axis=1)

# %%
df

# %%
x_idep

# %% [markdown]
# -------

# %% [markdown]
# # Logistic Regression

# %%
#AVERAGE OF DEPENDENT VARIABLE
(sum(df.Quantity)/(len(df.Quantity)))

# %%
# CONVERTING NUMERIC DEPENDENT VARIABLE TO CATEGORICAL DEPENDENT VARIABLE
# ABOVE AVERAGE = 0
# BELOW AVERAGE = 1
y =[]
for i in range(0,len(df.Quantity)):
    x = np.array(df.Quantity)
    if x[i] > 319.1954377311961:
        y.append(0)
    else:
        y.append(1)
ydep = pd.DataFrame(y)
ydep

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x_idep,ydep, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
modelfit = model.fit(xtrain,ytrain)

# %%
from sklearn.metrics import r2_score

# %%
lr_r2 = r2_score(ytest,modelfit.predict(xtest))
lr_r2

# %%
import math

# %%
from sklearn.metrics import mean_squared_error

# %%
modelfit.predict(xtest)

# %%
import statsmodels.api as sm

# %%
np.array(xtrain).shape

# %%
np.array(ytrain).shape

# %%
model1 = sm.Logit(np.array(ytrain)[:1000],np.array(xtrain)[:1000])

# %%
model1fit = model1.fit()

# %%
model1fit.summary2()

# %%
# PREDICTED PROBABILITY OF YTEST
model1fit.predict(xtest)

# %%
model1fit.predict(xtest).index

# %%
df.Quantity[1683]

# %%
# PREDICTED YTEST VALUE BY MULTIPLYING THE YTEST WITH PREDICTED PROBABILITY VALUE
Actu = []
for x in model1fit.predict(xtest).index:
    Actu.append(df.Quantity[x])
Actual=np.array(Actu)
predicted_prob = np.array(model1fit.predict(xtest))
Predicted_val = Actual*predicted_prob
pd.DataFrame(Predicted_val)

# %%
from sklearn.metrics import mean_squared_error

# %%
import math

# %%
# ROOT MEAN SQUARE ERROR
lr_rmse=math.sqrt(mean_squared_error(Actual,Predicted_val))
lr_rmse

# %% [markdown]
# ____________

# %% [markdown]
# y_dep= df.Quantity
# y_dep

# %%
y=df.Quantity
y

# %% [markdown]
# # Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn import preprocessing

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score, train_test_split

# %%
xtrain,xtest, ytrain,ytest = train_test_split(x_idep,y,test_size=0.2)

# %%
model_GB = GradientBoostingRegressor()

# %%
best_gbm = GridSearchCV(model_GB, param_grid={'learning_rate':[0.01,0.05,0.1],'max_depth':[1,2,3],
                                         'n_estimators':[100,200,500]}, cv=5, n_jobs=-1)

# %%
model_GBfit = model_GB.fit(xtrain,ytrain)

# %%
Predict_model1 = model_GBfit.predict(xtest)

# %%
# scores = cross_val_score(model_GB, xtrain, ytrain, cv=5)
# print("GBM Cross validation score: {0:.2%}".format(np.mean(scores), np.std(scores)*2))

# %%
from sklearn.metrics import mean_squared_error

# %%
import math

# %%
Actual = ytest

# %%
gbm_r2 = r2_score(Actual,Predict_model1)
gbm_r2

# %%
gbm_rmse=math.sqrt(mean_squared_error(Actual,Predict_model1))
gbm_rmse

# %% [markdown]
# __________

# %% [markdown]
# # eXtreme Gradient Boosting

# %%
from xgboost import XGBRegressor

# %%
xgb = XGBRegressor()

# %%
best_xgb = GridSearchCV(xgb, param_grid={'learning_rate':[0.01,0.05,0.1],'max_depth':[1,2,3],
                                         'n_estimators':[100,200,500]}, cv=5, n_jobs=-1)

# %%
best_xgb.fit(xtrain,ytrain)

# %%
Predict_model2 = model_GBfit.predict(xtest)

# %%
# scores = cross_val_score(best_xgb.best_estimator_, x_idep,y, cv=5)
# print("XGBoost Cross validation score: {0:.2%}".format(np.mean(scores), np.std(scores)*2))

# %%
xgbm_r2 = r2_score(Actual,Predict_model2)
xgbm_r2

# %%
xgbm_rmse=math.sqrt(mean_squared_error(Actual,Predict_model1))
xgbm_rmse

# %% [markdown]
# __________

# %% [markdown]
# # K_Nearest_Neighbors Regressor

# %%
xtrain.columns

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor()

# %%
knn_model = knn.fit(xtrain,ytrain)

# %%
Predict_model3 = knn_model.predict(xtest)

# %%
knn_r2 = r2_score(Actual,Predict_model3)
knn_r2

# %%
knn_rmse=math.sqrt(mean_squared_error(Actual,Predict_model3))
knn_rmse

# %%
# scores = cross_val_score(knn, xtrain,ytrain, cv=5)

# %%
# print("Cross validation score: {0:.2%} )".format(np.mean(scores), np.std(scores)*2))

# %% [markdown]
# ______

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
Random_model = RandomForestRegressor()

# %%
Random_modelfit = Random_model.fit(xtrain,ytrain)

# %%
Predict_model4 = Random_modelfit.predict(xtest)

# %%
rf_r2 = r2_score(Actual,Predict_model4)
rf_r2

# %%
rf_rmse=math.sqrt(mean_squared_error(Actual,Predict_model4))
rf_rmse

# %%
scores = cross_val_score(Random_model, xtrain,ytrain, cv=5)

# %%
print("Cross validation score: {0:.2%})".format(np.mean(scores), np.std(scores)*2))

# %% [markdown]
# _________

# %% [markdown]
# # Artificial Neural Network

# %%
from sklearn.preprocessing import scale

# %%
x_idep = scale(x_idep)
x_idep

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x_idep,y,test_size=0.2)

# %%
xtrain.shape, xtest.shape

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model1 = Sequential()

# %%
input_shape = xtrain[0].shape

# %%
model1.add(Dense(50,input_shape=input_shape))

# %%
model1.add(Dense(20,activation='relu'))

# %%
model1.add(Dense(30,activation='relu'))

# %%
model1.add(Dense(1,activation='relu'))

# %%
model1.summary()

# %%
model1.compile(optimizer='adam',loss='mean_squared_error')

# %%
model1.fit(xtrain,ytrain,epochs=50)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import math

# %%
model1.predict(xtest)

# %%
mean_absolute_error(ytest,model1.predict(xtest))

# %%
ann_r2 = r2_score(ytest,model1.predict(xtest))
ann_r2

# %%
ann_rmse = math.sqrt(mean_squared_error(ytest,model1.predict(xtest)))
ann_rmse

# %% [markdown]
# ___________

# %% [markdown]
# # Gradio

# %%
import gradio as gd

# %%
df1.isnull().sum()

# %%
df1

# %%
# taking only the fields which is selected after feature selection
df1=df1.drop("PoNumber",axis=1)
df1=df1.drop("SaleType",axis=1)
df1=df1.drop("Typecode",axis=1)
df1=df1.drop("Productcode",axis=1)
df1=df1.drop("Description",axis=1)
df1=df1.drop("LotNumber",axis=1)
df1=df1.drop("PaymentTerm",axis=1)
df1

# %%
x_indep1=df1.drop("Quantity",axis=1)
x_indep1

# %%
Month = gd.inputs.Dropdown(['January', 'February', 'March', 'April', 'May', 'June', 'July',
       'August', 'September', 'October', 'November', 'December'],label='Month')

# %%
Costsectioncode = gd.inputs.Dropdown(["120",  "13",  "11", "309",  "19",  "68", "302", "114",  "83", "108", "270", "352"],
                                     label='Costsectioncode')

# %%
Groupcode = gd.inputs.Dropdown(['LED BULBS', 'DL-PRM', 'DL-RECH', 'AA', 'FANS', 'RHL', 'AAA', 'DS',
       'IRON', 'MIXER GRINDERS', 'GAS STOVE', 'EL APP', '600 AAA',
       '700 AA', 'LUM', 'DL-POP', 'FS', '2100AA', 'IMMERSION ROD',
       'ROOM HEATER', 'DL-BR', 'ELECTRIC KETTLE', 'COMBIPACK',
       'JUICER MIXER GRINDER', 'POP-UP TOASTERS', 'SANDWICH MAKERS', 'CS',
       'WATER HEATER', 'JUICER', 'OTG', 'DET POW', 'AIR PURIFIER',
       'FOOD PROCESSOR'],label='Groupcode')

# %%
CustomerName = gd.inputs.Dropdown(['WAL-MART INDIA PRIVATE LIMITED - AMARAVATI',
       'WAL-MART INDIA PRIVATE LIMITED - AURANGABAD',
       'AvenueSupermartsLtd - Mumbai', 'Booker India Pvt Ltd',
       'Flipkart India Pvt. Ltd', 'More Retail Limited',
       'RELIANCE RETAIL LIMITED', 'METRO CASH & CARRY INDIA',
       'BOOKER SATNAM WHOLESALE PRIVATE LTD', 'Future Retail Limited',
       'WAL-MART INDIA PRIVATE LIMITED', 'Future Retail Limited.',
       'SUPERMARKET GROCERY SUPPLIES PRIVATE LIMITED',
       'FUTURE RETAIL LIMITED - AHMEDNAGAR',
       'WAL-MART INDIA PRIVATE LIMITED - RAIPUR',
       'WAL-MART INDIA PRIVATE LIMITED - BHOPAL I',
       'WAL-MART INDIA PRIVATE LIMITED - INDORE',
       'WAL-MART INDIA PRIVATE LIMITED - BHOPAL II',
       'Metro Cash & Carry - Indore', 'Wal-Mart India Pvt. Ltd.',
       'SPENCERS RETAIL LTD', 'ARAMBAGH FOODMART PVT LTD',
       'FLIPKART INDIA Pvt.Ltd', 'Flipkart India Pvt Ltd',
       'WAL-MART INDIA PRIVATE LIMITED - LUCKNOW',
       'WAL-MART INDIA PRIVATE LIMITED - GUNTUR',
       'WAL-MART INDIA PRIVATE LIMITED - VIJAWADA',
       'METRO CASH & CARRY - VIJAYAWADA',
       'WAL-MART INDIA PRIVATE LIMITED - RAJAMUNDRY',
       'Reliance Retail Limited',
       'METRO Cash & Carry India Private Limited',
       'WAL-MART INDIA PRIVATE LIMITED - HYDERABAD',
       'METRO CASH & CARRY INDIA PRIVATE LIMITED',
       'TALLAM ENTERPRISES - HYD', 'Metro Cash & Carry',
       'Future Retail Limited ( Formaly Heritage Fresh)',
       'AvenueSupermartsLtd.', 'FUTURE RETAIL LIMITED',
       'Max Hypermarket India Pvt Ltd',
       'CP WHOLESALE INDIA PRIVATE LIMITED',
       'WAL-MART INDIA PRIVATE LIMITED - AGRA',
       'WAL-MART INDIA PRIVATE LIMITED - MEERUT',
       'METRO CASH & CARRY INDIA PVT.LTD', 'METRO CASH & CARRY -  Delhi',
       'CP Wholesale India Private Limited',
       'Flipkart India Private Limited', 'Flipkart India Pvt. Ltd.',
       'MAX Hypermarket India Pvt. Ltd (ROH)',
       'WAL-MART INDIA PRIVATE LIMITED - JAIPUR', 'Avenue Supermarts Ltd',
       'Metro Cash & Carry Pvt. Ltd', 'M K RETAIL COMPANY',
       'MAX Hypermarket India Pvt. Ltd (BGL)',
       'METRO CASH & CARRY INDIA PVT LTD', 'Cloudtail India Pvt Ltd',
       'Metro Cash & Carry India Private Limited',
       'Amazon Wholesale (India) Private Limited',
       'METRO CASH AND CARRY INDIA PVT LTD',
       'Supermarket Grocery Suppliers Pvt Ltd', "SPENCER'S RETAIL LTD",
       'WAL-MART INDIA PRIVATE LIMITED - AMRISTAR',
       'WAL-MART INDIA PRIVATE LIMITED - ZIRAKPUR',
       'WAL-MART INDIA PRIVATE LIMITED - JALLANDER',
       'Metro Cash & Carry - Jallander',
       'WAL-MART INDIA PRIVATE LIMITED - BHATINDA',
       'WAL-MART INDIA PRIVATE LIMITED - LUDHIANA',
       'Metro Cash & Carry - Chandigarh',
       'WAL-MART INDIA PRIVATE LIMITED - JUMMU',
       'Infiniti Retail Limited',
       'Trent Hypermarket Private Limited - Bhiwandi',
       'VISHAL MEGA MART PVT LTD', 'Cloudtail India Private Liimited',
       'METRO CASH & CARRY', 'Saravana Store - Tex',
       'New Saravana Stores Brahmandamai - Padi',
       'CLOUDTAIL INDIA PRIVATE LIMITED',
       'NEW SARAVANA STORES - BRAMANDAMAI',
       'MAX Hypermarket India Pvt. Ltd (HYD)',
       'MAX Hypermarket India Pvt. Ltd (CBE)', 'THE CHENNAI SILKS',
       'FUTURE RETAIL LIMITED - Vijawada',
       'DJT RETAILERS PRIVATE LIMITED', 'BISMI HYPERMARKET PVT LTD',
       'RATNADEEP SUPER MARKET PVT LTD', 'Metro Cash & Carry - Amristar',
       'VISHAL MEGA MART PRIVATE LIMITED',
       'Aadhaar Wholesale Trading & Distr. Ltd',
       'Lulu Hypermarket , Kochi', 'DIVINE AGENCY',
       'DHANYA CONSUMERS PVT LTD', 'Lulu Hypermarket',
       'ANTZCO RETAIL PRIVATE LIMITED', 'Shanti Enterprise',
       'DEV MARKETING', 'AvenueSupermartsLtd',
       'Godfrey Phillips India Ltd', 'IDEALCOMBINATION',
       'HANDS ON TRADES PRIVATE LIMITED', 'Garima Marketing (I) Pvt Ltd',
       'Garima Marketing (I) Pvt Ltd-(Family Bazaar)',
       'Hands On Trades Pvt Ltd.', 'EMAMI FRANK ROSS LTD',
       'FLIPKART INDIA PRIVATE LIMITED', 'KHANDELWAL & COMPANY'],label='CustomerName')

# %%
Nsv = gd.inputs.Dropdown([10748.4,
 2903.6,
 1935.8,
 9720.0,
 69152.8,
 8067.76,
 8825.76,
 12216.0,
 8542.4,
 5829.0,
 14957.0,
 6108.0,
 455424.0,
 177380.0,
 816768.0,
 624096.0,
 3864.0,
 9384.000000000002,
 21960.0,
 10980.0,
 18768.0,
 320.31,
 0.0,
 93432.6,
 230190.4,
 2311.86,
 12918.36,
 1525.42,
 4576.32,
 14240.0,
 7120.0,
 2372.8,
 1962.8400000000001,
 3813.6,
 7624.0,
 3304.0,
 10236.0,
 3073.5,
 6352.0,
 8988.0,
 30672.0,
 2562.5,
 2489.5,
 27967.68,
 18645.12,
 4203.38,
 31525.350000000002,
 8939.16,
 5959.4400000000005,
 14915.300000000001,
 14406.800000000001,
 19491.5,
 21695.0,
 10932.2,
 12415.5,
 9932.4,
 2483.1,
 9322.560000000001,
 2711.8,
 7474.6,
 99600.0,
 131040.0,
 40896.0,
 44940.0,
 12812.5,
 744.4,
 6071.0,
 10500.0,
 21248.5,
 13552.0,
 15184.0,
 19368.0,
 8115.3,
 4046.04,
 2167.56,
 9684.0,
 6694.92,
 4449.150000000001,
 4745.76,
 5508.47,
 213.16,
 192.25,
 63.54,
 60.33,
 128.56,
 380.51,
 127.89,
 522.32,
 26.54,
 232.46,
 648.19,
 1525.42,
 2518.64,
 1526.27,
 1831.58,
 63.730000000000004,
 62.34,
 1144.45,
 289.36,
 156.36,
 369.21,
 686.44,
 49.97,
 58.82,
 1864.41,
 12.32,
 18.31,
 108.58,
 58.730000000000004,
 58.17,
 487.29,
 5084.75,
 4576.27,
 21.900000000000002,
 117.58,
 15.8,
 1048.09,
 1694.92,
 406.78000000000003,
 610.17,
 576.27,
 1372.88,
 1305.08,
 1059.32,
 3101.69,
 399.15000000000003,
 1632.2,
 5.92,
 9.72,
 62.54,
 1151.69,
 54.46,
 105.37,
 166.74,
 56.45,
 1906.78,
 5296.61,
 3474.58,
 1262.71,
 1211.8600000000001,
 350.0,
 200.89000000000001,
 4110.17,
 61.61,
 63.39,
 5932.2,
 4262.71,
 3360.17,
 644.07,
 361.02,
 281.36,
 1381.3600000000001,
 466.0,
 58.93,
 20.86,
 113.39,
 109.82000000000001,
 533.66,
 18.96,
 19.830000000000002,
 102.0],label='Lp')

# %%
df1.info()

# %%
def mod(Month, Costsectioncode,Groupcode,CustomerName,Nsv,UnitWeight,Lp):
    x1 = [Month, Costsectioncode,Groupcode,CustomerName,Nsv,UnitWeight,Lp]
    # Input is converted into dataframe and added at the end of the data
    x1 =pd.DataFrame(np.array(x1).reshape(1,-1),columns=x_indep1.columns)
    xtrain1 = df1.drop('Quantity',axis=1)
    xtrain1 = xtrain1.append(x1,ignore_index = True)
    for x in xtrain1.columns:
        # Organisation_code and Costsection_code are integer varaible so not encoded
        if x != 'Nsv' and x != 'UnitWeight' and x != 'Lp' and x!= 'Costsectioncode' and x!= 'Quantity':
            xtrain1[x] = LabelEncoder().fit_transform(xtrain1[x])
    # since we added our input to end of the data so to extract that one iloc[-1,:] is used
    x2 = xtrain1.iloc[-1,:]
    # Gradient Model is used in Gradio
    # To change model in Gradio - apply fitted model in pred varaible
    pred = Random_modelfit.predict(np.array(x2).reshape(1,-1))
    return pred

# %%
gd.Interface(mod, [Month, Costsectioncode,Groupcode,CustomerName,Nsv,UnitWeight,Lp],
             gd.outputs.Textbox(label='Quantity')).launch()

# %% [markdown]
# # Conclusion

# %%
R_f  = {'R2':rf_r2,'RMSE':rf_rmse}
L_R = {'R2':lr_r2,'RMSE':lr_rmse}
G_B_R = {'R2':gbm_r2,'RMSE':gbm_rmse}
e_G_B = {'R2':xgbm_r2,'RMSE':xgbm_rmse}
K_N_N = {'R2':knn_r2,'RMSE':knn_rmse}
ANN = {'R2':ann_r2,'RMSE':ann_rmse}

# %%
DataFrame = pd.DataFrame(data=[R_f,L_R,G_B_R,e_G_B,K_N_N,ANN],index=["Random forest Regressor ","Logistic Regression",
                                                                     "Gradient Boosting Regressor","eXtreme Gradient Boosting Regressor",
                                                                  "K Nearest Neighbour Regressor","Artifical Neural Network"])
pd.options.display.precision = 2
DataFrame
